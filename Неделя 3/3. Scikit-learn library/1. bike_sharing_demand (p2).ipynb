# %% [markdown]
# # SKLearn

# %% [markdown]
# ## Bike Sharing Demand

# %% [markdown]
# По историческим данным о прокате велосипедов и погодным условиям необходимо оценить спрос на прокат велосипедов

# %% [markdown]
# В наборе признаков присутствуют вещественные, категориальные и бинарные данные

# %% [markdown]
# Для демонстрации используется обучающая выборка из исходных данных train.csv, файлы для работы прилагаются

# %% [markdown]
# ## Библиотеки

# %%
from sklearn import cross_validation, grid_search, linear_model, metrics, pipeline, preprocessing

import numpy as np
import pandas as pd
import os

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Загрузка данных

# %%
path = os.path.join('datasets', 'bike_sharing_demand.csv')
raw_data = pd.read_csv(path, header=0, sep=',')

# %%
raw_data.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Обучение и отложенный тест

# %%
raw_data.datetime = raw_data.datetime.apply(pd.to_datetime)

# %%
raw_data['month'] = raw_data.datetime.apply(lambda x: x.month)
raw_data['hour'] = raw_data.datetime.apply(lambda x: x.hour)

# %%
train_data = raw_data.iloc[:-1000, :]
hold_out_test_data = raw_data.iloc[-1000:, :]

# %%
print(raw_data.shape, train_data.shape, hold_out_test_data.shape)
# Out:
# (10886, 14) (9886, 14) (1000, 14)

# %%
train_labels = train_data['count'].values
train_data = train_data.drop(['datetime', 'count', 'casual', 'registered'], axis=1)

# %%
test_labels = hold_out_test_data['count'].values
test_data = hold_out_test_data.drop(['datetime', 'count', 'casual', 'registered'], axis=1)

# %%
binary_data_columns = ['holiday', 'workingday']
binary_data_indices = np.array([(column in binary_data_columns) for column in train_data.columns], dtype=bool)

# %%
print(binary_data_columns)
# Out:
# ['holiday', 'workingday']

# %%
print(binary_data_indices)
# Out:
# [False  True  True False False False False False False False]

# %%
categorical_data_columns = ['season', 'weather', 'month']
categorical_data_indices = np.array([(column in categorical_data_columns) for column in train_data.columns], dtype=bool)

# %%
print(categorical_data_columns)
# Out:
# ['season', 'weather', 'month']

# %%
print(categorical_data_indices)
# Out:
# [ True False False  True False False False False  True False]

# %%
numeric_data_columns = ['temp', 'atemp', 'humidity', 'windspeed', 'month', 'hour']
numeric_data_indices = np.array([(column in numeric_data_columns) for column in train_data.columns], dtype=bool)

# %%
numeric_data_columns
# Out:
# ['temp', 'atemp', 'humidity', 'windspeed', 'month', 'hour']

# %%
numeric_data_indices
# Out:
# array([False, False, False, False,  True,  True,  True,  True,  True,
#         True])

# %% [markdown]
# #### Pipeline

# %%
regressor = linear_model.SGDRegressor(random_state=0, n_iter=3, loss='squared_loss', penalty='l2')

# %%
estimator = pipeline.Pipeline(steps=[
    ('feature_preprocessing', pipeline.FeatureUnion(transformer_list = [
        ('binary_variables_preprocessing', preprocessing.FunctionTransformer(lambda data: data[:, binary_data_indices])),
        ('numeric_vatiables_preprocessing', pipeline.Pipeline(steps=[
            ('selecting', preprocessing.FunctionTransformer(lambda data: data[:, numeric_data_indices])),
            ('scaling', preprocessing.StandardScaler(with_mean=0.))
        ])),
        ('categorical_variables_preprocessing', pipeline.Pipeline(steps=[
            ('selecting', preprocessing.FunctionTransformer(lambda data: data[:, categorical_data_indices])),
            ('hot_encoding', preprocessing.OneHotEncoder(handle_unknown='ignore'))
        ]))   
    ])),
    ('model_fitting', regressor)
    ]
)

# %%
estimator.fit(train_data, train_labels)
# Out:
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# Pipeline(memory=None,
#      steps=[('feature_preprocessing', FeatureUnion(n_jobs=1,
#        transformer_list=[('binary_variables_preprocessing', FunctionTransformer(accept_sparse=False,
#           func=<function <lambda> at 0x0000029AD5E0D620>, inv_kw_args=None,
#           inverse_func=None, kw_args=None, pass_y='deprecated',
#    ...,
#        power_t=0.25, random_state=0, shuffle=True, tol=None, verbose=0,
#        warm_start=False))])

# %%
metrics.mean_absolute_error(test_labels, estimator.predict(test_data))
# Out:
# 120.82144006542809

# %% [markdown]
# #### Подбор параметров

# %%
print(estimator.get_params().keys())
# Out:
# dict_keys(['memory', 'steps', 'feature_preprocessing', 'model_fitting', 'feature_preprocessing__n_jobs', 'feature_preprocessing__transformer_list', 'feature_preprocessing__transformer_weights', 'feature_preprocessing__binary_variables_preprocessing', 'feature_preprocessing__numeric_vatiables_preprocessing', 'feature_preprocessing__categorical_variables_preprocessing', 'feature_preprocessing__binary_variables_preprocessing__accept_sparse', 'feature_preprocessing__binary_variables_preprocessing__func', 'feature_preprocessing__binary_variables_preprocessing__inv_kw_args', 'feature_preprocessing__binary_variables_preprocessing__inverse_func', 'feature_preprocessing__binary_variables_preprocessing__kw_args', 'feature_preprocessing__binary_variables_preprocessing__pass_y', 'feature_preprocessing__binary_variables_preprocessing__validate', 'feature_preprocessing__numeric_vatiables_preprocessing__memory', 'feature_preprocessing__numeric_vatiables_preprocessing__steps', 'feature_preprocessing__numeric_vatiables_preprocessing__selecting', 'feature_preprocessing__numeric_vatiables_preprocessing__scaling', 'feature_preprocessing__numeric_vatiables_preprocessing__selecting__accept_sparse', 'feature_preprocessing__numeric_vatiables_preprocessing__selecting__func', 'feature_preprocessing__numeric_vatiables_preprocessing__selecting__inv_kw_args', 'feature_preprocessing__numeric_vatiables_preprocessing__selecting__inverse_func', 'feature_preprocessing__numeric_vatiables_preprocessing__selecting__kw_args', 'feature_preprocessing__numeric_vatiables_preprocessing__selecting__pass_y', 'feature_preprocessing__numeric_vatiables_preprocessing__selecting__validate', 'feature_preprocessing__numeric_vatiables_preprocessing__scaling__copy', 'feature_preprocessing__numeric_vatiables_preprocessing__scaling__with_mean', 'feature_preprocessing__numeric_vatiables_preprocessing__scaling__with_std', 'feature_preprocessing__categorical_variables_preprocessing__memory', 'feature_preprocessing__categorical_variables_preprocessing__steps', 'feature_preprocessing__categorical_variables_preprocessing__selecting', 'feature_preprocessing__categorical_variables_preprocessing__hot_encoding', 'feature_preprocessing__categorical_variables_preprocessing__selecting__accept_sparse', 'feature_preprocessing__categorical_variables_preprocessing__selecting__func', 'feature_preprocessing__categorical_variables_preprocessing__selecting__inv_kw_args', 'feature_preprocessing__categorical_variables_preprocessing__selecting__inverse_func', 'feature_preprocessing__categorical_variables_preprocessing__selecting__kw_args', 'feature_preprocessing__categorical_variables_preprocessing__selecting__pass_y', 'feature_preprocessing__categorical_variables_preprocessing__selecting__validate', 'feature_preprocessing__categorical_variables_preprocessing__hot_encoding__categorical_features', 'feature_preprocessing__categorical_variables_preprocessing__hot_encoding__dtype', 'feature_preprocessing__categorical_variables_preprocessing__hot_encoding__handle_unknown', 'feature_preprocessing__categorical_variables_preprocessing__hot_encoding__n_values', 'feature_preprocessing__categorical_variables_preprocessing__hot_encoding__sparse', 'model_fitting__alpha', 'model_fitting__average', 'model_fitting__epsilon', 'model_fitting__eta0', 'model_fitting__fit_intercept', 'model_fitting__l1_ratio', 'model_fitting__learning_rate', 'model_fitting__loss', 'model_fitting__max_iter', 'model_fitting__n_iter', 'model_fitting__penalty', 'model_fitting__power_t', 'model_fitting__random_state', 'model_fitting__shuffle', 'model_fitting__tol', 'model_fitting__verbose', 'model_fitting__warm_start'])

# %%
parameters_grid = {
    'model_fitting__alpha': [.0001, .001, .01],
    'model_fitting__eta0': [.001, 0.05]
}

# %%
grid_cv = grid_search.GridSearchCV(estimator, parameters_grid, scoring='mean_absolute_error', cv=4)

# %%
# %%time
grid_cv.fit(train_data, train_labels)
# Out:
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# Wall time: 547 ms
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\vlnlo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# GridSearchCV(cv=4, error_score='raise',
#        estimator=Pipeline(memory=None,
#      steps=[('feature_preprocessing', FeatureUnion(n_jobs=1,
#        transformer_list=[('binary_variables_preprocessing', FunctionTransformer(accept_sparse=False,
#           func=<function <lambda> at 0x0000029AD5E0D620>, inv_kw_args=None,
#           inverse_func=None, kw_args=None, pass_y='deprecated',
#    ...,
#        power_t=0.25, random_state=0, shuffle=True, tol=None, verbose=0,
#        warm_start=False))]),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'model_fitting__alpha': [0.0001, 0.001, 0.01], 'model_fitting__eta0': [0.001, 0.05]},
#        pre_dispatch='2*n_jobs', refit=True, scoring='mean_absolute_error',
#        verbose=0)

# %%
print(grid_cv.best_params_)
# Out:
# {'model_fitting__alpha': 0.01, 'model_fitting__eta0': 0.05}

# %%
print(grid_cv.best_score_)
# Out:
# -106.59260761001322

# %% [markdown]
# #### Оценка по отложенному тесту

# %%
test_predictions = grid_cv.best_estimator_.predict(test_data)

# %%
metrics.mean_absolute_error(test_labels, test_predictions)
# Out:
# 129.27978020997608

# %%
print(test_labels[:20])
# Out:
# [525 835 355 222 228 325 328 308 346 446 943 838 531 432 195 181 199  49
#   17  16]

# %%
print(test_predictions[:20])
# Out:
# [144.64376856 172.30990187 218.22501306 252.63793875 269.70856583
#  269.9495088  291.43509324 322.48223923 325.87836813 337.95337606
#  335.79933706 326.73282524 308.14432385 289.18594975 276.12967877
#  238.89077159 245.21254514  50.59988096  58.1332855   65.66669004]

# %%
pylab.figure(figsize=(8, 6))
pylab.grid()
pylab.scatter(train_labels, grid_cv.best_estimator_.predict(train_data), alpha=0.5, color='red')
pylab.scatter(test_labels, grid_cv.best_estimator_.predict(test_data), alpha=0.5, color='blue')
pylab.xlim(-100, 1100)
pylab.ylim(-100, 1100)
# Out:
# (-100, 1100)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor = RandomForestRegressor(random_state=0, max_depth=20, n_estimators=50)

# %%
estimator = pipeline.Pipeline(steps=[
    ('feature_preprocessing', pipeline.FeatureUnion(transformer_list = [
        ('binary_variables_preprocessing', preprocessing.FunctionTransformer(lambda data: data[:, binary_data_indices])),
        ('numeric_vatiables_preprocessing', pipeline.Pipeline(steps=[
            ('selecting', preprocessing.FunctionTransformer(lambda data: data[:, numeric_data_indices])),
            ('scaling', preprocessing.StandardScaler(with_mean=0.))
        ])),
        ('categorical_variables_preprocessing', pipeline.Pipeline(steps=[
            ('selecting', preprocessing.FunctionTransformer(lambda data: data[:, categorical_data_indices])),
            ('hot_encoding', preprocessing.OneHotEncoder(handle_unknown='ignore'))
        ]))   
    ])),
    ('model_fitting', regressor)
    ]
)

# %%
estimator.fit(train_data, train_labels)
# Out:
# Pipeline(memory=None,
#      steps=[('feature_preprocessing', FeatureUnion(n_jobs=1,
#        transformer_list=[('binary_variables_preprocessing', FunctionTransformer(accept_sparse=False,
#           func=<function <lambda> at 0x0000029AD6227AE8>, inv_kw_args=None,
#           inverse_func=None, kw_args=None, pass_y='deprecated',
#    ..._estimators=50, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False))])

# %%
metrics.mean_absolute_error(test_labels, estimator.predict(test_data))
# Out:
# 79.70102812235277

# %%
test_labels[:10]
# Out:
# array([525, 835, 355, 222, 228, 325, 328, 308, 346, 446], dtype=int64)

# %%
estimator.predict(test_data)[:10]
# Out:
# array([399.484     , 498.94      , 259.89095238, 168.22974183,
#        207.34808887, 269.85813168, 274.43748506, 329.90594729,
#        289.75397589, 447.23      ])

# %%
pylab.figure(figsize=(16, 6))

pylab.subplot(1, 2, 1)
pylab.grid()
pylab.scatter(train_labels, estimator.predict(train_data), alpha=0.5, color='red')
pylab.scatter(test_labels, estimator.predict(test_data), alpha=0.5, color='blue')
pylab.title('random forest model')
pylab.xlim(-100, 1100)
pylab.ylim(-100, 1100)

pylab.subplot(1, 2, 2)
pylab.grid()
pylab.scatter(train_labels, grid_cv.best_estimator_.predict(train_data), alpha=0.5, color='red')
pylab.scatter(test_labels, grid_cv.best_estimator_.predict(test_data), alpha=0.5, color='blue')
pylab.title('linear model')
pylab.xlim(-100, 1100)
pylab.ylim(-100, 1100)
# Out:
# (-100, 1100)
